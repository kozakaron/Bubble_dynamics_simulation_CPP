# %%
import importlib
from interface import python_interface as api
importlib.reload(api)
cpar=api.example_cpar()

cpar = {'ID': 0,
 'mechanism': 'chemkin_kaust2023_ammonia',
 'R_E': 30.0e-06,
 'ratio': 1.0,
 'species': ['H2','N2'],#['H2','N2','O2','AR','HE','H2O'],#['N2H3','O','NH2','NO','H'],
 'fractions': [0.75,0.25],#[0.25,0.20,0.05,0.07,0.12,0.31],#[0.3,0.25,0.2,0.15,0.1],
 'P_amb': 1.0e5,#101325.0,
 'T_inf': 298.15,
 'alpha_M': 0.35,
 'P_v': 2338.1,
 'mu_L': 0.001,
 'rho_L': 998.2,
 'c_L': 1483.0,
 'surfactant': 1.0,
 'enable_heat_transfer': True,
 'enable_evaporation': False,
 'enable_reactions': True,
 'enable_dissipated_energy': True,
 'enable_van_der_waals': True,
 'enable_rate_thresholding': True,
 'target_specie': 'NH3',
 'excitation_type': 'sinusoid',#'no_excitation',#'sinusoid',#'sin_impulse',
 'excitation_params': [-2.12121e5, 45.4031e3],#[-2.12121e5, 45.4031e3],# [], 
 'excitation_cycles': 1.0,
 'ramp_up_cycles': 0.0,
 'R_and_R_dot_from_file': 1, #0: nothing to read in, chemistry is coupled to bubble dynamics; 1: R_dot is calculated here, 2: it is read from *.csv
 'rows': 1,
 'cols': 1,
 'file_name': 'test.csv' #'output_01.csv',#'output_50.csv'
       }
print(cpar['file_name'])
print('Please check, where you R_dotdot read in from!')

#data=api.run_simulation(cpar,executable_path="./bin/main",t_max=0.0004,timeout=300.0,save_steps=True)
#cpar: dict, json_path: str = 'ignore.json', executable_path: str = './bin/main', t_max: float = 1.0, timeout: float = 60.0, save_steps: bool = True, save_jacobian: bool = False, show_output: bool = True
#api.plot(data)

ps=api.example_parameter_study()

ps['mechanism'] = 'chemkin_kaust2023_ammonia'
ps['R_E'] = {"type": "Const", "value": 160.0e-6}
ps['ratio'] = {"type": "Const", "value": 1.0}
ps['species'] = ['H2','N2']
ps['fractions'] = [0.75,0.25]
ps['P_amb'] = {"type": "Const", "value": 1.0e5}
ps['T_inf'] = {"type": "Const", "value": 298.15}
ps['alpha_M'] = {"type": "Const", "value": 0.35}
ps['P_v'] = {"type": "Const", "value": 2338.1}
ps['mu_L'] = {"type": "Const", "value": 0.001}
ps['rho_L'] = {"type": "Const", "value": 998.2}
ps['c_L'] = {"type": "Const", "value": 1483.0}
ps['surfactant'] = {"type": "Const", "value": 1.0}
ps['enable_heat_transfer'] = True
ps['enable_evaporation'] = False
ps['enable_reactions'] = True
ps['enable_dissipated_energy'] = True
ps['enable_van_der_waals'] = True
ps['enable_rate_thresholding'] = True
ps['target_specie'] = 'NH3'
ps['excitation_type'] = 'sinusoid'
ps['excitation_params'] = [
    {"type":"LinearRange","start":-1.0e5,"end":-3.0e5,"num_steps":100},#-2.12121e5}, #p_A
    {"type":"LogRange","start":2.0e3,"end":20.0e3,"num_steps":100}#{"type": "Const", "value": 25.0e3}#45.4031e3} #freq
]
ps['excitation_cycles'] = {"type": "Const", "value": 1.0}
ps['ramp_up_cycles'] = {"type": "Const", "value": 0.0}
ps['R_and_R_dot_from_file'] = {"type": "Const", "value": 0.0}
ps['rows'] = {"type": "Const", "value": 1.0}
ps['cols'] = {"type": "Const", "value": 1.0}
ps['file_name'] = 'test.csv'

#api.run_parameter_study(ps,save_directory='par_study')

#datas=api.read_parameter_study('par_study1/')

api.run_parameter_study(ps) #,save_directory='par_study'

datas=api.read_parameter_study('par_study1/')
# Out:
# executable_path='./bin/main', system='wsl'
# test.csv
# Please check, where you R_dotdot read in from!
# [stderr] 2026.03.16 16:24:04: (preprocess) Loaded mechanism "chemkin_kaust2023_ammonia" from "mechanism/json_files/chemkin_kaust2023_ammonia.json" in 17.72 ms. in ./src/parameters.cpp:600: get_parameters();
# [stdout] Running parameter study with 8 threads...
# [stdout] test.csv
# [stdout] test.csv
# [stdout] test.csv
# [stdout] test.csv
# [stdout] test.csv
# [stdout] test.csv
# [stdout] test.csv
# [stdout] test.csv
# [stdout]     0/10000: success; runtime=   1.681 s; num_steps=    7303;   |   p_A=-1.0000e+05 Pa; freq=2.0000e+03 Hz;    |   energy_demand=5.0244e+07 MJ/kg (best=5.0244e+07 MJ/kg)
# [stdout] test.csv
# [stdout]     1/10000: success; runtime=   1.828 s; num_steps=    7681;   |   p_A=-1.0202e+05 Pa; freq=2.0000e+03 Hz;    |   energy_demand=2.9112e+07 MJ/kg (best=2.9112e+07 MJ/kg)
# [stdout] test.csv
# [stdout]     2/10000: success; runtime=   1.979 s; num_steps=    7965;   |   p_A=-1.0404e+05 Pa; freq=2.0000e+03 Hz;    |   energy_demand=1.7133e+07 MJ/kg (best=1.7133e+07 MJ/kg)
# [stdout] test.csv
# [stdout]     3/10000: success; runtime=   1.992 s; num_steps=    7902;   |   p_A=-1.0606e+05 Pa; freq=2.0000e+03 Hz;    |   energy_demand=1.1330e+06 MJ/kg (best=1.1330e+06 MJ/kg)
# [stdout] test.csv
# [stdout]     4/10000: success; runtime=   2.065 s; num_steps=    8123;   |   p_A=-1.0808e+05 Pa; freq=2.0000e+03 Hz;    |   energy_demand=9.8845e+04 MJ/kg (best=9.8845e+04 MJ/kg)
# [stdout] test.csv
# [stdout]     5/10000: success; runtime=   2.088 s; num_steps=    8167;   |   p_A=-1.1010e+05 Pa; freq=2.0000e+03 Hz;    |   energy_demand=1.2308e+04 MJ/kg (best=1.2308e+04 MJ/kg)
# [stdout] test.csv
# [stdout]     6/10000: success; runtime=   2.110 s; num_steps=    8248;   |   p_A=-1.1212e+05 Pa; freq=2.0000e+03 Hz;    |   energy_demand=2.0807e+03 MJ/kg (best=2.0807e+03 MJ/kg)
# [stdout] test.csv
# [stdout]     7/10000: success; runtime=   2.143 s; num_steps=    8257;   |   p_A=-1.1414e+05 Pa; freq=2.0000e+03 Hz;    |   energy_demand=9.7093e+02 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]     8/10000: success; runtime=   2.052 s; num_steps=    8319;   |   p_A=-1.1616e+05 Pa; freq=2.0000e+03 Hz;    |   energy_demand=1.0459e+03 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]     9/10000: success; runtime=   2.127 s; num_steps=    8364;   |   p_A=-1.1818e+05 Pa; freq=2.0000e+03 Hz;    |   energy_demand=1.2084e+03 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]    10/10000: success; runtime=   2.167 s; num_steps=    8346;   |   p_A=-1.2020e+05 Pa; freq=2.0000e+03 Hz;    |   energy_demand=1.4201e+03 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]    11/10000: success; runtime=   2.184 s; num_steps=    8487;   |   p_A=-1.2222e+05 Pa; freq=2.0000e+03 Hz;    |   energy_demand=1.6839e+03 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]    12/10000: success; runtime=   2.144 s; num_steps=    8397;   |   p_A=-1.2424e+05 Pa; freq=2.0000e+03 Hz;    |   energy_demand=2.0056e+03 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]    13/10000: success; runtime=   2.151 s; num_steps=    8399;   |   p_A=-1.2626e+05 Pa; freq=2.0000e+03 Hz;    |   energy_demand=2.3928e+03 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]    14/10000: success; runtime=   2.164 s; num_steps=    8512;   |   p_A=-1.2828e+05 Pa; freq=2.0000e+03 Hz;    |   energy_demand=2.8533e+03 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]    15/10000: success; runtime=   2.217 s; num_steps=    8587;   |   p_A=-1.3030e+05 Pa; freq=2.0000e+03 Hz;    |   energy_demand=3.3959e+03 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]    16/10000: success; runtime=   2.282 s; num_steps=    8558;   |   p_A=-1.3232e+05 Pa; freq=2.0000e+03 Hz;    |   energy_demand=4.0293e+03 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]    17/10000: success; runtime=   2.229 s; num_steps=    8592;   |   p_A=-1.3434e+05 Pa; freq=2.0000e+03 Hz;    |   energy_demand=4.7630e+03 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]    19/10000: success; runtime=   2.259 s; num_steps=    8809;   |   p_A=-1.3838e+05 Pa; freq=2.0000e+03 Hz;    |   energy_demand=6.5697e+03 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]    18/10000: success; runtime=   2.299 s; num_steps=    8737;   |   p_A=-1.3636e+05 Pa; freq=2.0000e+03 Hz;    |   energy_demand=5.6066e+03 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]    22/10000: success; runtime=   2.197 s; num_steps=    8605;   |   p_A=-1.4444e+05 Pa; freq=2.0000e+03 Hz;    |   energy_demand=1.0278e+04 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]    20/10000: success; runtime=   2.286 s; num_steps=    8693;   |   p_A=-1.4040e+05 Pa; freq=2.0000e+03 Hz;    |   energy_demand=7.6624e+03 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]    21/10000: success; runtime=   2.280 s; num_steps=    8822;   |   p_A=-1.4242e+05 Pa; freq=2.0000e+03 Hz;    |   energy_demand=8.8951e+03 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]    23/10000: success; runtime=   2.218 s; num_steps=    8651;   |   p_A=-1.4646e+05 Pa; freq=2.0000e+03 Hz;    |   energy_demand=1.1824e+04 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]    24/10000: success; runtime=   2.170 s; num_steps=    8583;   |   p_A=-1.4848e+05 Pa; freq=2.0000e+03 Hz;    |   energy_demand=1.3543e+04 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]    25/10000: success; runtime=   2.216 s; num_steps=    8684;   |   p_A=-1.5051e+05 Pa; freq=2.0000e+03 Hz;    |   energy_demand=1.5445e+04 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]    26/10000: success; runtime=   2.213 s; num_steps=    8572;   |   p_A=-1.5253e+05 Pa; freq=2.0000e+03 Hz;    |   energy_demand=1.7542e+04 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]    27/10000: success; runtime=   2.234 s; num_steps=    8671;   |   p_A=-1.5455e+05 Pa; freq=2.0000e+03 Hz;    |   energy_demand=1.9841e+04 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]    28/10000: success; runtime=   2.251 s; num_steps=    8667;   |   p_A=-1.5657e+05 Pa; freq=2.0000e+03 Hz;    |   energy_demand=2.2353e+04 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]    29/10000: success; runtime=   2.267 s; num_steps=    8683;   |   p_A=-1.5859e+05 Pa; freq=2.0000e+03 Hz;    |   energy_demand=2.5087e+04 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]    30/10000: success; runtime=   2.322 s; num_steps=    8828;   |   p_A=-1.6061e+05 Pa; freq=2.0000e+03 Hz;    |   energy_demand=2.8052e+04 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]    31/10000: success; runtime=   2.292 s; num_steps=    8847;   |   p_A=-1.6263e+05 Pa; freq=2.0000e+03 Hz;    |   energy_demand=3.1258e+04 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]    32/10000: success; runtime=   2.319 s; num_steps=    8874;   |   p_A=-1.6465e+05 Pa; freq=2.0000e+03 Hz;    |   energy_demand=3.4715e+04 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]    33/10000: success; runtime=   2.440 s; num_steps=    8798;   |   p_A=-1.6667e+05 Pa; freq=2.0000e+03 Hz;    |   energy_demand=3.8432e+04 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]    34/10000: success; runtime=   2.410 s; num_steps=    9113;   |   p_A=-1.6869e+05 Pa; freq=2.0000e+03 Hz;    |   energy_demand=4.2422e+04 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]    35/10000: success; runtime=   2.437 s; num_steps=    8893;   |   p_A=-1.7071e+05 Pa; freq=2.0000e+03 Hz;    |   energy_demand=4.6693e+04 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]    36/10000: success; runtime=   2.419 s; num_steps=    8965;   |   p_A=-1.7273e+05 Pa; freq=2.0000e+03 Hz;    |   energy_demand=5.1258e+04 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]    37/10000: success; runtime=   2.503 s; num_steps=    9038;   |   p_A=-1.7475e+05 Pa; freq=2.0000e+03 Hz;    |   energy_demand=5.6129e+04 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]    38/10000: success; runtime=   2.496 s; num_steps=    9001;   |   p_A=-1.7677e+05 Pa; freq=2.0000e+03 Hz;    |   energy_demand=6.1316e+04 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]    39/10000: success; runtime=   2.578 s; num_steps=    8861;   |   p_A=-1.7879e+05 Pa; freq=2.0000e+03 Hz;    |   energy_demand=6.6832e+04 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]    40/10000: success; runtime=   2.516 s; num_steps=    8959;   |   p_A=-1.8081e+05 Pa; freq=2.0000e+03 Hz;    |   energy_demand=7.2689e+04 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]    41/10000: success; runtime=   2.454 s; num_steps=    8663;   |   p_A=-1.8283e+05 Pa; freq=2.0000e+03 Hz;    |   energy_demand=7.8897e+04 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]    44/10000: success; runtime=   2.442 s; num_steps=    8779;   |   p_A=-1.8889e+05 Pa; freq=2.0000e+03 Hz;    |   energy_demand=9.9765e+04 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]    43/10000: success; runtime=   2.468 s; num_steps=    8971;   |   p_A=-1.8687e+05 Pa; freq=2.0000e+03 Hz;    |   energy_demand=9.2424e+04 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]    42/10000: success; runtime=   2.550 s; num_steps=    8686;   |   p_A=-1.8485e+05 Pa; freq=2.0000e+03 Hz;    |   energy_demand=8.5472e+04 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]    45/10000: success; runtime=   2.477 s; num_steps=    8751;   |   p_A=-1.9091e+05 Pa; freq=2.0000e+03 Hz;    |   energy_demand=1.0750e+05 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]    46/10000: success; runtime=   2.619 s; num_steps=    9077;   |   p_A=-1.9293e+05 Pa; freq=2.0000e+03 Hz;    |   energy_demand=1.1566e+05 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]    47/10000: success; runtime=   2.513 s; num_steps=    8787;   |   p_A=-1.9495e+05 Pa; freq=2.0000e+03 Hz;    |   energy_demand=1.2423e+05 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]    48/10000: success; runtime=   2.489 s; num_steps=    8896;   |   p_A=-1.9697e+05 Pa; freq=2.0000e+03 Hz;    |   energy_demand=1.3323e+05 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]    49/10000: success; runtime=   2.501 s; num_steps=    8891;   |   p_A=-1.9899e+05 Pa; freq=2.0000e+03 Hz;    |   energy_demand=1.4267e+05 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]    50/10000: success; runtime=   2.481 s; num_steps=    8720;   |   p_A=-2.0101e+05 Pa; freq=2.0000e+03 Hz;    |   energy_demand=1.5256e+05 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]    52/10000: success; runtime=   2.501 s; num_steps=    8769;   |   p_A=-2.0505e+05 Pa; freq=2.0000e+03 Hz;    |   energy_demand=1.7373e+05 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]    51/10000: success; runtime=   2.566 s; num_steps=    9201;   |   p_A=-2.0303e+05 Pa; freq=2.0000e+03 Hz;    |   energy_demand=1.6291e+05 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]    53/10000: success; runtime=   2.587 s; num_steps=    8889;   |   p_A=-2.0707e+05 Pa; freq=2.0000e+03 Hz;    |   energy_demand=1.8503e+05 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]    54/10000: success; runtime=   2.623 s; num_steps=    8965;   |   p_A=-2.0909e+05 Pa; freq=2.0000e+03 Hz;    |   energy_demand=1.9682e+05 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]    55/10000: success; runtime=   2.618 s; num_steps=    9128;   |   p_A=-2.1111e+05 Pa; freq=2.0000e+03 Hz;    |   energy_demand=2.0910e+05 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]    56/10000: success; runtime=   2.619 s; num_steps=    8961;   |   p_A=-2.1313e+05 Pa; freq=2.0000e+03 Hz;    |   energy_demand=2.2189e+05 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]    57/10000: success; runtime=   2.681 s; num_steps=    9083;   |   p_A=-2.1515e+05 Pa; freq=2.0000e+03 Hz;    |   energy_demand=2.3520e+05 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]    58/10000: success; runtime=   2.690 s; num_steps=    9129;   |   p_A=-2.1717e+05 Pa; freq=2.0000e+03 Hz;    |   energy_demand=2.4903e+05 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]    59/10000: success; runtime=   2.699 s; num_steps=    9238;   |   p_A=-2.1919e+05 Pa; freq=2.0000e+03 Hz;    |   energy_demand=2.6340e+05 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]    60/10000: success; runtime=   2.672 s; num_steps=    9204;   |   p_A=-2.2121e+05 Pa; freq=2.0000e+03 Hz;    |   energy_demand=2.7831e+05 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]    61/10000: success; runtime=   2.628 s; num_steps=    9077;   |   p_A=-2.2323e+05 Pa; freq=2.0000e+03 Hz;    |   energy_demand=2.9377e+05 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]    62/10000: success; runtime=   2.656 s; num_steps=    9213;   |   p_A=-2.2525e+05 Pa; freq=2.0000e+03 Hz;    |   energy_demand=3.0980e+05 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]    63/10000: success; runtime=   2.681 s; num_steps=    9298;   |   p_A=-2.2727e+05 Pa; freq=2.0000e+03 Hz;    |   energy_demand=3.2640e+05 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]    64/10000: success; runtime=   2.683 s; num_steps=    9371;   |   p_A=-2.2929e+05 Pa; freq=2.0000e+03 Hz;    |   energy_demand=3.4357e+05 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]    65/10000: success; runtime=   2.679 s; num_steps=    9295;   |   p_A=-2.3131e+05 Pa; freq=2.0000e+03 Hz;    |   energy_demand=3.6134e+05 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]    66/10000: success; runtime=   2.620 s; num_steps=    9063;   |   p_A=-2.3333e+05 Pa; freq=2.0000e+03 Hz;    |   energy_demand=3.7970e+05 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]    67/10000: success; runtime=   2.620 s; num_steps=    9050;   |   p_A=-2.3535e+05 Pa; freq=2.0000e+03 Hz;    |   energy_demand=3.9867e+05 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]    68/10000: success; runtime=   2.684 s; num_steps=    9267;   |   p_A=-2.3737e+05 Pa; freq=2.0000e+03 Hz;    |   energy_demand=4.1826e+05 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]    69/10000: success; runtime=   2.684 s; num_steps=    9097;   |   p_A=-2.3939e+05 Pa; freq=2.0000e+03 Hz;    |   energy_demand=4.3848e+05 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]    71/10000: success; runtime=   2.564 s; num_steps=    8814;   |   p_A=-2.4343e+05 Pa; freq=2.0000e+03 Hz;    |   energy_demand=4.8083e+05 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]    70/10000: success; runtime=   2.649 s; num_steps=    8909;   |   p_A=-2.4141e+05 Pa; freq=2.0000e+03 Hz;    |   energy_demand=4.5933e+05 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]    72/10000: success; runtime=   2.659 s; num_steps=    8917;   |   p_A=-2.4545e+05 Pa; freq=2.0000e+03 Hz;    |   energy_demand=5.0298e+05 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]    73/10000: success; runtime=   2.708 s; num_steps=    8859;   |   p_A=-2.4747e+05 Pa; freq=2.0000e+03 Hz;    |   energy_demand=5.2580e+05 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]    74/10000: success; runtime=   2.679 s; num_steps=    8958;   |   p_A=-2.4949e+05 Pa; freq=2.0000e+03 Hz;    |   energy_demand=5.4929e+05 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]    75/10000: success; runtime=   2.705 s; num_steps=    8923;   |   p_A=-2.5152e+05 Pa; freq=2.0000e+03 Hz;    |   energy_demand=5.7346e+05 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]    76/10000: success; runtime=   2.665 s; num_steps=    8905;   |   p_A=-2.5354e+05 Pa; freq=2.0000e+03 Hz;    |   energy_demand=5.9831e+05 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]    77/10000: success; runtime=   2.711 s; num_steps=    8960;   |   p_A=-2.5556e+05 Pa; freq=2.0000e+03 Hz;    |   energy_demand=6.2387e+05 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]    78/10000: success; runtime=   2.646 s; num_steps=    8999;   |   p_A=-2.5758e+05 Pa; freq=2.0000e+03 Hz;    |   energy_demand=6.5012e+05 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]    79/10000: success; runtime=   2.682 s; num_steps=    8835;   |   p_A=-2.5960e+05 Pa; freq=2.0000e+03 Hz;    |   energy_demand=6.7708e+05 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]    80/10000: success; runtime=   2.740 s; num_steps=    9079;   |   p_A=-2.6162e+05 Pa; freq=2.0000e+03 Hz;    |   energy_demand=7.0476e+05 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]    81/10000: success; runtime=   2.700 s; num_steps=    9084;   |   p_A=-2.6364e+05 Pa; freq=2.0000e+03 Hz;    |   energy_demand=7.3316e+05 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]    82/10000: success; runtime=   2.653 s; num_steps=    9112;   |   p_A=-2.6566e+05 Pa; freq=2.0000e+03 Hz;    |   energy_demand=7.6228e+05 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]    84/10000: success; runtime=   2.750 s; num_steps=    9160;   |   p_A=-2.6970e+05 Pa; freq=2.0000e+03 Hz;    |   energy_demand=8.2273e+05 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]    83/10000: success; runtime=   2.855 s; num_steps=    9187;   |   p_A=-2.6768e+05 Pa; freq=2.0000e+03 Hz;    |   energy_demand=7.9214e+05 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]    86/10000: success; runtime=   2.786 s; num_steps=    9309;   |   p_A=-2.7374e+05 Pa; freq=2.0000e+03 Hz;    |   energy_demand=8.8613e+05 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]    85/10000: success; runtime=   2.964 s; num_steps=    9424;   |   p_A=-2.7172e+05 Pa; freq=2.0000e+03 Hz;    |   energy_demand=8.5406e+05 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]    87/10000: success; runtime=   3.076 s; num_steps=    9469;   |   p_A=-2.7576e+05 Pa; freq=2.0000e+03 Hz;    |   energy_demand=9.1896e+05 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]    88/10000: success; runtime=   3.344 s; num_steps=    9345;   |   p_A=-2.7778e+05 Pa; freq=2.0000e+03 Hz;    |   energy_demand=9.5254e+05 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]    89/10000: success; runtime=   3.135 s; num_steps=    9531;   |   p_A=-2.7980e+05 Pa; freq=2.0000e+03 Hz;    |   energy_demand=9.8687e+05 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]    90/10000: success; runtime=   3.127 s; num_steps=    9499;   |   p_A=-2.8182e+05 Pa; freq=2.0000e+03 Hz;    |   energy_demand=1.0220e+06 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]    91/10000: success; runtime=   3.114 s; num_steps=    9358;   |   p_A=-2.8384e+05 Pa; freq=2.0000e+03 Hz;    |   energy_demand=1.0578e+06 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]    92/10000: success; runtime=   3.183 s; num_steps=    9632;   |   p_A=-2.8586e+05 Pa; freq=2.0000e+03 Hz;    |   energy_demand=1.0944e+06 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]    93/10000: success; runtime=   3.348 s; num_steps=    9648;   |   p_A=-2.8788e+05 Pa; freq=2.0000e+03 Hz;    |   energy_demand=1.1318e+06 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]    94/10000: success; runtime=   3.318 s; num_steps=    9530;   |   p_A=-2.8990e+05 Pa; freq=2.0000e+03 Hz;    |   energy_demand=1.1699e+06 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]    95/10000: success; runtime=   3.121 s; num_steps=    9695;   |   p_A=-2.9192e+05 Pa; freq=2.0000e+03 Hz;    |   energy_demand=1.2088e+06 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]   100/10000: success; runtime=   1.687 s; num_steps=    7514;   |   p_A=-1.0000e+05 Pa; freq=2.0471e+03 Hz;    |   energy_demand=6.9506e+07 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]   101/10000: success; runtime=   1.823 s; num_steps=    7595;   |   p_A=-1.0202e+05 Pa; freq=2.0471e+03 Hz;    |   energy_demand=2.6205e+07 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]    96/10000: success; runtime=   2.983 s; num_steps=    9789;   |   p_A=-2.9394e+05 Pa; freq=2.0000e+03 Hz;    |   energy_demand=1.2485e+06 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]    97/10000: success; runtime=   2.933 s; num_steps=    9730;   |   p_A=-2.9596e+05 Pa; freq=2.0000e+03 Hz;    |   energy_demand=1.2889e+06 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]   102/10000: success; runtime=   1.994 s; num_steps=    7742;   |   p_A=-1.0404e+05 Pa; freq=2.0471e+03 Hz;    |   energy_demand=2.1185e+07 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]    98/10000: success; runtime=   2.992 s; num_steps=    9666;   |   p_A=-2.9798e+05 Pa; freq=2.0000e+03 Hz;    |   energy_demand=1.3301e+06 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]   103/10000: success; runtime=   2.074 s; num_steps=    7979;   |   p_A=-1.0606e+05 Pa; freq=2.0471e+03 Hz;    |   energy_demand=1.3786e+06 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]    99/10000: success; runtime=   3.004 s; num_steps=    9812;   |   p_A=-3.0000e+05 Pa; freq=2.0000e+03 Hz;    |   energy_demand=1.3721e+06 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]   104/10000: success; runtime=   1.997 s; num_steps=    8128;   |   p_A=-1.0808e+05 Pa; freq=2.0471e+03 Hz;    |   energy_demand=1.1994e+05 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]   105/10000: success; runtime=   1.993 s; num_steps=    8151;   |   p_A=-1.1010e+05 Pa; freq=2.0471e+03 Hz;    |   energy_demand=1.5132e+04 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]   106/10000: success; runtime=   2.013 s; num_steps=    7994;   |   p_A=-1.1212e+05 Pa; freq=2.0471e+03 Hz;    |   energy_demand=2.5041e+03 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]   107/10000: success; runtime=   2.038 s; num_steps=    8216;   |   p_A=-1.1414e+05 Pa; freq=2.0471e+03 Hz;    |   energy_demand=9.8540e+02 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]   108/10000: success; runtime=   2.080 s; num_steps=    8117;   |   p_A=-1.1616e+05 Pa; freq=2.0471e+03 Hz;    |   energy_demand=1.0169e+03 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]   109/10000: success; runtime=   2.075 s; num_steps=    8266;   |   p_A=-1.1818e+05 Pa; freq=2.0471e+03 Hz;    |   energy_demand=1.1690e+03 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]   110/10000: success; runtime=   2.097 s; num_steps=    8443;   |   p_A=-1.2020e+05 Pa; freq=2.0471e+03 Hz;    |   energy_demand=1.3685e+03 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]   111/10000: success; runtime=   2.144 s; num_steps=    8441;   |   p_A=-1.2222e+05 Pa; freq=2.0471e+03 Hz;    |   energy_demand=1.6165e+03 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]   112/10000: success; runtime=   2.088 s; num_steps=    8330;   |   p_A=-1.2424e+05 Pa; freq=2.0471e+03 Hz;    |   energy_demand=1.9181e+03 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]   113/10000: success; runtime=   2.226 s; num_steps=    8462;   |   p_A=-1.2626e+05 Pa; freq=2.0471e+03 Hz;    |   energy_demand=2.2798e+03 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]   114/10000: success; runtime=   2.216 s; num_steps=    8639;   |   p_A=-1.2828e+05 Pa; freq=2.0471e+03 Hz;    |   energy_demand=2.7088e+03 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]   115/10000: success; runtime=   2.229 s; num_steps=    8561;   |   p_A=-1.3030e+05 Pa; freq=2.0471e+03 Hz;    |   energy_demand=3.2128e+03 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]   116/10000: success; runtime=   2.223 s; num_steps=    8467;   |   p_A=-1.3232e+05 Pa; freq=2.0471e+03 Hz;    |   energy_demand=3.8000e+03 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]   117/10000: success; runtime=   2.212 s; num_steps=    8657;   |   p_A=-1.3434e+05 Pa; freq=2.0471e+03 Hz;    |   energy_demand=4.4788e+03 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]   118/10000: success; runtime=   2.200 s; num_steps=    8661;   |   p_A=-1.3636e+05 Pa; freq=2.0471e+03 Hz;    |   energy_demand=5.2582e+03 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]   119/10000: success; runtime=   2.197 s; num_steps=    8560;   |   p_A=-1.3838e+05 Pa; freq=2.0471e+03 Hz;    |   energy_demand=6.1472e+03 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]   120/10000: success; runtime=   2.165 s; num_steps=    8434;   |   p_A=-1.4040e+05 Pa; freq=2.0471e+03 Hz;    |   energy_demand=7.1559e+03 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]   121/10000: success; runtime=   2.209 s; num_steps=    8467;   |   p_A=-1.4242e+05 Pa; freq=2.0471e+03 Hz;    |   energy_demand=8.2949e+03 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]   122/10000: success; runtime=   2.245 s; num_steps=    8453;   |   p_A=-1.4444e+05 Pa; freq=2.0471e+03 Hz;    |   energy_demand=9.5744e+03 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]   123/10000: success; runtime=   2.200 s; num_steps=    8484;   |   p_A=-1.4646e+05 Pa; freq=2.0471e+03 Hz;    |   energy_demand=1.1004e+04 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]   124/10000: success; runtime=   2.176 s; num_steps=    8569;   |   p_A=-1.4848e+05 Pa; freq=2.0471e+03 Hz;    |   energy_demand=1.2594e+04 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]   125/10000: success; runtime=   2.212 s; num_steps=    8407;   |   p_A=-1.5051e+05 Pa; freq=2.0471e+03 Hz;    |   energy_demand=1.4353e+04 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]   126/10000: success; runtime=   2.264 s; num_steps=    8684;   |   p_A=-1.5253e+05 Pa; freq=2.0471e+03 Hz;    |   energy_demand=1.6290e+04 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]   127/10000: success; runtime=   2.292 s; num_steps=    8569;   |   p_A=-1.5455e+05 Pa; freq=2.0471e+03 Hz;    |   energy_demand=1.8415e+04 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]   128/10000: success; runtime=   2.270 s; num_steps=    8643;   |   p_A=-1.5657e+05 Pa; freq=2.0471e+03 Hz;    |   energy_demand=2.0734e+04 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]   129/10000: success; runtime=   2.270 s; num_steps=    8850;   |   p_A=-1.5859e+05 Pa; freq=2.0471e+03 Hz;    |   energy_demand=2.3258e+04 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]   130/10000: success; runtime=   2.382 s; num_steps=    8683;   |   p_A=-1.6061e+05 Pa; freq=2.0471e+03 Hz;    |   energy_demand=2.5994e+04 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]   131/10000: success; runtime=   2.323 s; num_steps=    8834;   |   p_A=-1.6263e+05 Pa; freq=2.0471e+03 Hz;    |   energy_demand=2.8950e+04 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]   132/10000: success; runtime=   2.391 s; num_steps=    8902;   |   p_A=-1.6465e+05 Pa; freq=2.0471e+03 Hz;    |   energy_demand=3.2136e+04 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]   133/10000: success; runtime=   2.331 s; num_steps=    8820;   |   p_A=-1.6667e+05 Pa; freq=2.0471e+03 Hz;    |   energy_demand=3.5560e+04 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]   134/10000: success; runtime=   2.391 s; num_steps=    8747;   |   p_A=-1.6869e+05 Pa; freq=2.0471e+03 Hz;    |   energy_demand=3.9232e+04 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]   135/10000: success; runtime=   2.409 s; num_steps=    8862;   |   p_A=-1.7071e+05 Pa; freq=2.0471e+03 Hz;    |   energy_demand=4.3161e+04 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]   136/10000: success; runtime=   2.393 s; num_steps=    8775;   |   p_A=-1.7273e+05 Pa; freq=2.0471e+03 Hz;    |   energy_demand=4.7357e+04 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]   137/10000: success; runtime=   2.485 s; num_steps=    9055;   |   p_A=-1.7475e+05 Pa; freq=2.0471e+03 Hz;    |   energy_demand=5.1832e+04 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]   138/10000: success; runtime=   2.402 s; num_steps=    8818;   |   p_A=-1.7677e+05 Pa; freq=2.0471e+03 Hz;    |   energy_demand=5.6595e+04 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]   140/10000: success; runtime=   2.369 s; num_steps=    8647;   |   p_A=-1.8081e+05 Pa; freq=2.0471e+03 Hz;    |   energy_demand=6.7037e+04 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]   139/10000: success; runtime=   2.466 s; num_steps=    9069;   |   p_A=-1.7879e+05 Pa; freq=2.0471e+03 Hz;    |   energy_demand=6.1660e+04 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]   141/10000: success; runtime=   2.430 s; num_steps=    8712;   |   p_A=-1.8283e+05 Pa; freq=2.0471e+03 Hz;    |   energy_demand=7.2740e+04 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]   142/10000: success; runtime=   2.374 s; num_steps=    8792;   |   p_A=-1.8485e+05 Pa; freq=2.0471e+03 Hz;    |   energy_demand=7.8778e+04 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]   143/10000: success; runtime=   2.417 s; num_steps=    8773;   |   p_A=-1.8687e+05 Pa; freq=2.0471e+03 Hz;    |   energy_demand=8.5162e+04 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]   144/10000: success; runtime=   2.544 s; num_steps=    8850;   |   p_A=-1.8889e+05 Pa; freq=2.0471e+03 Hz;    |   energy_demand=9.1903e+04 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]   145/10000: success; runtime=   2.463 s; num_steps=    8837;   |   p_A=-1.9091e+05 Pa; freq=2.0471e+03 Hz;    |   energy_demand=9.9009e+04 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]   146/10000: success; runtime=   2.405 s; num_steps=    8790;   |   p_A=-1.9293e+05 Pa; freq=2.0471e+03 Hz;    |   energy_demand=1.0649e+05 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]   148/10000: success; runtime=   2.376 s; num_steps=    8717;   |   p_A=-1.9697e+05 Pa; freq=2.0471e+03 Hz;    |   energy_demand=1.2262e+05 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]   147/10000: success; runtime=   2.467 s; num_steps=    8932;   |   p_A=-1.9495e+05 Pa; freq=2.0471e+03 Hz;    |   energy_demand=1.1436e+05 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]   149/10000: success; runtime=   2.465 s; num_steps=    8891;   |   p_A=-1.9899e+05 Pa; freq=2.0471e+03 Hz;    |   energy_demand=1.3128e+05 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]   150/10000: success; runtime=   2.502 s; num_steps=    9077;   |   p_A=-2.0101e+05 Pa; freq=2.0471e+03 Hz;    |   energy_demand=1.4036e+05 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]   151/10000: success; runtime=   2.575 s; num_steps=    8798;   |   p_A=-2.0303e+05 Pa; freq=2.0471e+03 Hz;    |   energy_demand=1.4985e+05 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]   152/10000: success; runtime=   2.540 s; num_steps=    8880;   |   p_A=-2.0505e+05 Pa; freq=2.0471e+03 Hz;    |   energy_demand=1.5978e+05 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]   153/10000: success; runtime=   2.563 s; num_steps=    9099;   |   p_A=-2.0707e+05 Pa; freq=2.0471e+03 Hz;    |   energy_demand=1.7015e+05 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]   154/10000: success; runtime=   2.648 s; num_steps=    9193;   |   p_A=-2.0909e+05 Pa; freq=2.0471e+03 Hz;    |   energy_demand=1.8096e+05 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]   155/10000: success; runtime=   2.612 s; num_steps=    9155;   |   p_A=-2.1111e+05 Pa; freq=2.0471e+03 Hz;    |   energy_demand=1.9222e+05 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]   156/10000: success; runtime=   2.578 s; num_steps=    8874;   |   p_A=-2.1313e+05 Pa; freq=2.0471e+03 Hz;    |   energy_demand=2.0395e+05 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]   157/10000: success; runtime=   2.562 s; num_steps=    9288;   |   p_A=-2.1515e+05 Pa; freq=2.0471e+03 Hz;    |   energy_demand=2.1615e+05 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]   158/10000: success; runtime=   2.633 s; num_steps=    8963;   |   p_A=-2.1717e+05 Pa; freq=2.0471e+03 Hz;    |   energy_demand=2.2883e+05 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]   159/10000: success; runtime=   2.658 s; num_steps=    9235;   |   p_A=-2.1919e+05 Pa; freq=2.0471e+03 Hz;    |   energy_demand=2.4200e+05 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]   160/10000: success; runtime=   2.647 s; num_steps=    9326;   |   p_A=-2.2121e+05 Pa; freq=2.0471e+03 Hz;    |   energy_demand=2.5566e+05 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]   161/10000: success; runtime=   2.659 s; num_steps=    9149;   |   p_A=-2.2323e+05 Pa; freq=2.0471e+03 Hz;    |   energy_demand=2.6983e+05 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]   162/10000: success; runtime=   2.652 s; num_steps=    9187;   |   p_A=-2.2525e+05 Pa; freq=2.0471e+03 Hz;    |   energy_demand=2.8451e+05 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]   164/10000: success; runtime=   2.632 s; num_steps=    9134;   |   p_A=-2.2929e+05 Pa; freq=2.0471e+03 Hz;    |   energy_demand=3.1544e+05 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]   163/10000: success; runtime=   2.720 s; num_steps=    9364;   |   p_A=-2.2727e+05 Pa; freq=2.0471e+03 Hz;    |   energy_demand=2.9971e+05 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]   165/10000: success; runtime=   2.652 s; num_steps=    9078;   |   p_A=-2.3131e+05 Pa; freq=2.0471e+03 Hz;    |   energy_demand=3.3171e+05 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]   166/10000: success; runtime=   2.619 s; num_steps=    9132;   |   p_A=-2.3333e+05 Pa; freq=2.0471e+03 Hz;    |   energy_demand=3.4852e+05 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]   167/10000: success; runtime=   2.618 s; num_steps=    9040;   |   p_A=-2.3535e+05 Pa; freq=2.0471e+03 Hz;    |   energy_demand=3.6589e+05 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]   168/10000: success; runtime=   2.556 s; num_steps=    9019;   |   p_A=-2.3737e+05 Pa; freq=2.0471e+03 Hz;    |   energy_demand=3.8382e+05 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]   169/10000: success; runtime=   2.481 s; num_steps=    8903;   |   p_A=-2.3939e+05 Pa; freq=2.0471e+03 Hz;    |   energy_demand=4.0232e+05 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]   171/10000: success; runtime=   2.480 s; num_steps=    9144;   |   p_A=-2.4343e+05 Pa; freq=2.0471e+03 Hz;    |   energy_demand=4.4108e+05 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]   170/10000: success; runtime=   2.548 s; num_steps=    9004;   |   p_A=-2.4141e+05 Pa; freq=2.0471e+03 Hz;    |   energy_demand=4.2141e+05 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]   172/10000: success; runtime=   2.464 s; num_steps=    8848;   |   p_A=-2.4545e+05 Pa; freq=2.0471e+03 Hz;    |   energy_demand=4.6135e+05 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]   173/10000: success; runtime=   2.441 s; num_steps=    8902;   |   p_A=-2.4747e+05 Pa; freq=2.0471e+03 Hz;    |   energy_demand=4.8221e+05 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]   174/10000: success; runtime=   2.497 s; num_steps=    9038;   |   p_A=-2.4949e+05 Pa; freq=2.0471e+03 Hz;    |   energy_demand=5.0369e+05 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]   175/10000: success; runtime=   2.420 s; num_steps=    8916;   |   p_A=-2.5152e+05 Pa; freq=2.0471e+03 Hz;    |   energy_demand=5.2579e+05 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]   176/10000: success; runtime=   2.337 s; num_steps=    8835;   |   p_A=-2.5354e+05 Pa; freq=2.0471e+03 Hz;    |   energy_demand=5.4850e+05 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]   177/10000: success; runtime=   2.334 s; num_steps=    9109;   |   p_A=-2.5556e+05 Pa; freq=2.0471e+03 Hz;    |   energy_demand=5.7185e+05 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]   178/10000: success; runtime=   2.430 s; num_steps=    8956;   |   p_A=-2.5758e+05 Pa; freq=2.0471e+03 Hz;    |   energy_demand=5.9583e+05 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]   180/10000: success; runtime=   2.432 s; num_steps=    9240;   |   p_A=-2.6162e+05 Pa; freq=2.0471e+03 Hz;    |   energy_demand=6.4572e+05 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]   179/10000: success; runtime=   2.517 s; num_steps=    9196;   |   p_A=-2.5960e+05 Pa; freq=2.0471e+03 Hz;    |   energy_demand=6.2045e+05 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]   181/10000: success; runtime=   2.367 s; num_steps=    9202;   |   p_A=-2.6364e+05 Pa; freq=2.0471e+03 Hz;    |   energy_demand=6.7164e+05 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]   182/10000: success; runtime=   2.466 s; num_steps=    9123;   |   p_A=-2.6566e+05 Pa; freq=2.0471e+03 Hz;    |   energy_demand=6.9821e+05 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]   183/10000: success; runtime=   2.451 s; num_steps=    9268;   |   p_A=-2.6768e+05 Pa; freq=2.0471e+03 Hz;    |   energy_demand=7.2543e+05 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]   184/10000: success; runtime=   2.538 s; num_steps=    9163;   |   p_A=-2.6970e+05 Pa; freq=2.0471e+03 Hz;    |   energy_demand=7.5333e+05 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]   185/10000: success; runtime=   2.580 s; num_steps=    9388;   |   p_A=-2.7172e+05 Pa; freq=2.0471e+03 Hz;    |   energy_demand=7.8189e+05 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]   187/10000: success; runtime=   2.516 s; num_steps=    9514;   |   p_A=-2.7576e+05 Pa; freq=2.0471e+03 Hz;    |   energy_demand=8.4103e+05 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]   186/10000: success; runtime=   2.587 s; num_steps=    9217;   |   p_A=-2.7374e+05 Pa; freq=2.0471e+03 Hz;    |   energy_demand=8.1113e+05 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]   188/10000: success; runtime=   2.602 s; num_steps=    9450;   |   p_A=-2.7778e+05 Pa; freq=2.0471e+03 Hz;    |   energy_demand=8.7162e+05 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]   189/10000: success; runtime=   2.595 s; num_steps=    9446;   |   p_A=-2.7980e+05 Pa; freq=2.0471e+03 Hz;    |   energy_demand=9.0288e+05 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]   190/10000: success; runtime=   2.621 s; num_steps=    9483;   |   p_A=-2.8182e+05 Pa; freq=2.0471e+03 Hz;    |   energy_demand=9.3483e+05 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]   191/10000: success; runtime=   2.651 s; num_steps=    9540;   |   p_A=-2.8384e+05 Pa; freq=2.0471e+03 Hz;    |   energy_demand=9.6746e+05 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]   192/10000: success; runtime=   2.687 s; num_steps=    9802;   |   p_A=-2.8586e+05 Pa; freq=2.0471e+03 Hz;    |   energy_demand=1.0008e+06 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]   193/10000: success; runtime=   2.678 s; num_steps=    9671;   |   p_A=-2.8788e+05 Pa; freq=2.0471e+03 Hz;    |   energy_demand=1.0348e+06 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]   194/10000: success; runtime=   2.581 s; num_steps=    9640;   |   p_A=-2.8990e+05 Pa; freq=2.0471e+03 Hz;    |   energy_demand=1.0695e+06 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]   195/10000: success; runtime=   2.709 s; num_steps=    9879;   |   p_A=-2.9192e+05 Pa; freq=2.0471e+03 Hz;    |   energy_demand=1.1049e+06 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]   197/10000: success; runtime=   2.707 s; num_steps=    9752;   |   p_A=-2.9596e+05 Pa; freq=2.0471e+03 Hz;    |   energy_demand=1.1777e+06 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]   196/10000: success; runtime=   2.741 s; num_steps=    9874;   |   p_A=-2.9394e+05 Pa; freq=2.0471e+03 Hz;    |   energy_demand=1.1409e+06 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]   200/10000: success; runtime=   1.571 s; num_steps=    7357;   |   p_A=-1.0000e+05 Pa; freq=2.0952e+03 Hz;    |   energy_demand=7.2312e+07 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]   198/10000: success; runtime=   2.813 s; num_steps=   10050;   |   p_A=-2.9798e+05 Pa; freq=2.0471e+03 Hz;    |   energy_demand=1.2152e+06 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]   199/10000: success; runtime=   2.723 s; num_steps=    9736;   |   p_A=-3.0000e+05 Pa; freq=2.0471e+03 Hz;    |   energy_demand=1.2533e+06 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]   201/10000: success; runtime=   1.678 s; num_steps=    7780;   |   p_A=-1.0202e+05 Pa; freq=2.0952e+03 Hz;    |   energy_demand=1.8133e+07 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]   202/10000: success; runtime=   1.746 s; num_steps=    7819;   |   p_A=-1.0404e+05 Pa; freq=2.0952e+03 Hz;    |   energy_demand=2.2204e+07 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]   203/10000: success; runtime=   1.797 s; num_steps=    7968;   |   p_A=-1.0606e+05 Pa; freq=2.0952e+03 Hz;    |   energy_demand=1.6730e+06 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]   205/10000: success; runtime=   1.767 s; num_steps=    8032;   |   p_A=-1.1010e+05 Pa; freq=2.0952e+03 Hz;    |   energy_demand=1.8528e+04 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]   204/10000: success; runtime=   1.804 s; num_steps=    7913;   |   p_A=-1.0808e+05 Pa; freq=2.0952e+03 Hz;    |   energy_demand=1.4434e+05 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]   206/10000: success; runtime=   1.863 s; num_steps=    8367;   |   p_A=-1.1212e+05 Pa; freq=2.0952e+03 Hz;    |   energy_demand=3.0455e+03 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]   207/10000: success; runtime=   1.906 s; num_steps=    8160;   |   p_A=-1.1414e+05 Pa; freq=2.0952e+03 Hz;    |   energy_demand=1.0276e+03 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]   208/10000: success; runtime=   1.882 s; num_steps=    8234;   |   p_A=-1.1616e+05 Pa; freq=2.0952e+03 Hz;    |   energy_demand=9.9355e+02 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]   209/10000: success; runtime=   1.972 s; num_steps=    8284;   |   p_A=-1.1818e+05 Pa; freq=2.0952e+03 Hz;    |   energy_demand=1.1350e+03 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]   210/10000: success; runtime=   2.004 s; num_steps=    8496;   |   p_A=-1.2020e+05 Pa; freq=2.0952e+03 Hz;    |   energy_demand=1.3222e+03 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]   211/10000: success; runtime=   1.995 s; num_steps=    8493;   |   p_A=-1.2222e+05 Pa; freq=2.0952e+03 Hz;    |   energy_demand=1.5546e+03 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]   213/10000: success; runtime=   1.993 s; num_steps=    8349;   |   p_A=-1.2626e+05 Pa; freq=2.0952e+03 Hz;    |   energy_demand=2.1731e+03 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]   212/10000: success; runtime=   1.998 s; num_steps=    8416;   |   p_A=-1.2424e+05 Pa; freq=2.0952e+03 Hz;    |   energy_demand=1.8363e+03 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]   214/10000: success; runtime=   2.035 s; num_steps=    8451;   |   p_A=-1.2828e+05 Pa; freq=2.0952e+03 Hz;    |   energy_demand=2.5714e+03 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]   215/10000: success; runtime=   2.049 s; num_steps=    8395;   |   p_A=-1.3030e+05 Pa; freq=2.0952e+03 Hz;    |   energy_demand=3.0384e+03 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]   216/10000: success; runtime=   2.025 s; num_steps=    8700;   |   p_A=-1.3232e+05 Pa; freq=2.0952e+03 Hz;    |   energy_demand=3.5815e+03 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]   217/10000: success; runtime=   2.084 s; num_steps=    8612;   |   p_A=-1.3434e+05 Pa; freq=2.0952e+03 Hz;    |   energy_demand=4.2088e+03 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]   218/10000: success; runtime=   2.050 s; num_steps=    8624;   |   p_A=-1.3636e+05 Pa; freq=2.0952e+03 Hz;    |   energy_demand=4.9291e+03 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]   219/10000: success; runtime=   2.004 s; num_steps=    8367;   |   p_A=-1.3838e+05 Pa; freq=2.0952e+03 Hz;    |   energy_demand=5.7519e+03 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]   220/10000: success; runtime=   2.036 s; num_steps=    8520;   |   p_A=-1.4040e+05 Pa; freq=2.0952e+03 Hz;    |   energy_demand=6.6864e+03 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]   221/10000: success; runtime=   2.076 s; num_steps=    8295;   |   p_A=-1.4242e+05 Pa; freq=2.0952e+03 Hz;    |   energy_demand=7.7416e+03 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]   222/10000: success; runtime=   2.116 s; num_steps=    8298;   |   p_A=-1.4444e+05 Pa; freq=2.0952e+03 Hz;    |   energy_demand=8.9265e+03 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]   223/10000: success; runtime=   2.049 s; num_steps=    8482;   |   p_A=-1.4646e+05 Pa; freq=2.0952e+03 Hz;    |   energy_demand=1.0250e+04 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]   224/10000: success; runtime=   2.113 s; num_steps=    8531;   |   p_A=-1.4848e+05 Pa; freq=2.0952e+03 Hz;    |   energy_demand=1.1720e+04 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]   225/10000: success; runtime=   2.142 s; num_steps=    8467;   |   p_A=-1.5051e+05 Pa; freq=2.0952e+03 Hz;    |   energy_demand=1.3346e+04 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]   226/10000: success; runtime=   2.206 s; num_steps=    8537;   |   p_A=-1.5253e+05 Pa; freq=2.0952e+03 Hz;    |   energy_demand=1.5136e+04 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]   227/10000: success; runtime=   2.328 s; num_steps=    8671;   |   p_A=-1.5455e+05 Pa; freq=2.0952e+03 Hz;    |   energy_demand=1.7097e+04 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]   228/10000: success; runtime=   2.394 s; num_steps=    8798;   |   p_A=-1.5657e+05 Pa; freq=2.0952e+03 Hz;    |   energy_demand=1.9238e+04 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]   229/10000: success; runtime=   2.376 s; num_steps=    8732;   |   p_A=-1.5859e+05 Pa; freq=2.0952e+03 Hz;    |   energy_demand=2.1566e+04 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]   230/10000: success; runtime=   2.525 s; num_steps=    8805;   |   p_A=-1.6061e+05 Pa; freq=2.0952e+03 Hz;    |   energy_demand=2.4088e+04 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]   231/10000: success; runtime=   2.560 s; num_steps=    8878;   |   p_A=-1.6263e+05 Pa; freq=2.0952e+03 Hz;    |   energy_demand=2.6813e+04 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]   232/10000: success; runtime=   2.569 s; num_steps=    8982;   |   p_A=-1.6465e+05 Pa; freq=2.0952e+03 Hz;    |   energy_demand=2.9747e+04 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]   233/10000: success; runtime=   2.490 s; num_steps=    8912;   |   p_A=-1.6667e+05 Pa; freq=2.0952e+03 Hz;    |   energy_demand=3.2899e+04 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]   234/10000: success; runtime=   2.500 s; num_steps=    8843;   |   p_A=-1.6869e+05 Pa; freq=2.0952e+03 Hz;    |   energy_demand=3.6277e+04 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]   235/10000: success; runtime=   2.575 s; num_steps=    8979;   |   p_A=-1.7071e+05 Pa; freq=2.0952e+03 Hz;    |   energy_demand=3.9889e+04 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]   236/10000: success; runtime=   2.462 s; num_steps=    8739;   |   p_A=-1.7273e+05 Pa; freq=2.0952e+03 Hz;    |   energy_demand=4.3746e+04 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]   237/10000: success; runtime=   2.470 s; num_steps=    8701;   |   p_A=-1.7475e+05 Pa; freq=2.0952e+03 Hz;    |   energy_demand=4.7858e+04 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]   238/10000: success; runtime=   2.470 s; num_steps=    8873;   |   p_A=-1.7677e+05 Pa; freq=2.0952e+03 Hz;    |   energy_demand=5.2235e+04 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]   239/10000: success; runtime=   2.431 s; num_steps=    8893;   |   p_A=-1.7879e+05 Pa; freq=2.0952e+03 Hz;    |   energy_demand=5.6890e+04 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# [stdout]   240/10000: success; runtime=   2.373 s; num_steps=    8579;   |   p_A=-1.8081e+05 Pa; freq=2.0952e+03 Hz;    |   energy_demand=6.1832e+04 MJ/kg (best=9.7093e+02 MJ/kg)
# [stdout] test.csv
# ...
# [stdout] test.csv
# [stdout]  9918/10000: success; runtime=   1.584 s; num_steps=    5922;   |   p_A=-1.3636e+05 Pa; freq=2.0000e+04 Hz;    |   energy_demand=4.5468e+07 MJ/kg (best=7.3380e+02 MJ/kg)
# [stdout] test.csv
# [stdout]  9921/10000: success; runtime=   1.422 s; num_steps=    6035;   |   p_A=-1.4242e+05 Pa; freq=2.0000e+04 Hz;    |   energy_demand=3.0294e+07 MJ/kg (best=7.3380e+02 MJ/kg)
# [stdout] test.csv
# [stdout]  9922/10000: success; runtime=   1.579 s; num_steps=    5935;   |   p_A=-1.4444e+05 Pa; freq=2.0000e+04 Hz;    |   energy_demand=5.5738e+07 MJ/kg (best=7.3380e+02 MJ/kg)
# [stdout] test.csv
# [stdout]  9923/10000: success; runtime=   1.597 s; num_steps=    5920;   |   p_A=-1.4646e+05 Pa; freq=2.0000e+04 Hz;    |   energy_demand=5.0815e+07 MJ/kg (best=7.3380e+02 MJ/kg)
# [stdout] test.csv
# [stdout]  9924/10000: success; runtime=   1.666 s; num_steps=    6281;   |   p_A=-1.4848e+05 Pa; freq=2.0000e+04 Hz;    |   energy_demand=4.3095e+07 MJ/kg (best=7.3380e+02 MJ/kg)
# [stdout] test.csv
# [stdout]  9925/10000: success; runtime=   1.364 s; num_steps=    5921;   |   p_A=-1.5051e+05 Pa; freq=2.0000e+04 Hz;    |   energy_demand=8.2101e+07 MJ/kg (best=7.3380e+02 MJ/kg)
# [stdout] test.csv
# [stdout]  9927/10000: success; runtime=   1.467 s; num_steps=    6064;   |   p_A=-1.5455e+05 Pa; freq=2.0000e+04 Hz;    |   energy_demand=3.5412e+07 MJ/kg (best=7.3380e+02 MJ/kg)
# [stdout] test.csv
# [stdout]  9926/10000: success; runtime=   1.585 s; num_steps=    6073;   |   p_A=-1.5253e+05 Pa; freq=2.0000e+04 Hz;    |   energy_demand=4.8652e+07 MJ/kg (best=7.3380e+02 MJ/kg)
# [stdout] test.csv
# [stdout]  9928/10000: success; runtime=   1.489 s; num_steps=    6169;   |   p_A=-1.5657e+05 Pa; freq=2.0000e+04 Hz;    |   energy_demand=7.3667e+07 MJ/kg (best=7.3380e+02 MJ/kg)
# [stdout] test.csv
# [stdout]  9929/10000: success; runtime=   1.594 s; num_steps=    6056;   |   p_A=-1.5859e+05 Pa; freq=2.0000e+04 Hz;    |   energy_demand=6.3354e+07 MJ/kg (best=7.3380e+02 MJ/kg)
# [stdout] test.csv
# [stdout]  9930/10000: success; runtime=   1.738 s; num_steps=    6260;   |   p_A=-1.6061e+05 Pa; freq=2.0000e+04 Hz;    |   energy_demand=4.9743e+07 MJ/kg (best=7.3380e+02 MJ/kg)
# [stdout] test.csv
# [stdout]  9931/10000: success; runtime=   1.667 s; num_steps=    6462;   |   p_A=-1.6263e+05 Pa; freq=2.0000e+04 Hz;    |   energy_demand=4.9860e+07 MJ/kg (best=7.3380e+02 MJ/kg)
# [stdout] test.csv
# [stdout]  9932/10000: success; runtime=   1.688 s; num_steps=    6693;   |   p_A=-1.6465e+05 Pa; freq=2.0000e+04 Hz;    |   energy_demand=6.8808e+07 MJ/kg (best=7.3380e+02 MJ/kg)
# [stdout] test.csv
# [stdout]  9933/10000: success; runtime=   1.716 s; num_steps=    6375;   |   p_A=-1.6667e+05 Pa; freq=2.0000e+04 Hz;    |   energy_demand=4.9047e+07 MJ/kg (best=7.3380e+02 MJ/kg)
# [stdout] test.csv
# [stdout]  9935/10000: success; runtime=   1.586 s; num_steps=    6467;   |   p_A=-1.7071e+05 Pa; freq=2.0000e+04 Hz;    |   energy_demand=4.1228e+07 MJ/kg (best=7.3380e+02 MJ/kg)
# [stdout] test.csv
# [stdout]  9934/10000: success; runtime=   1.732 s; num_steps=    6471;   |   p_A=-1.6869e+05 Pa; freq=2.0000e+04 Hz;    |   energy_demand=6.2849e+07 MJ/kg (best=7.3380e+02 MJ/kg)
# [stdout] test.csv
# [stdout]  9936/10000: success; runtime=   1.673 s; num_steps=    6334;   |   p_A=-1.7273e+05 Pa; freq=2.0000e+04 Hz;    |   energy_demand=4.0706e+07 MJ/kg (best=7.3380e+02 MJ/kg)
# [stdout] test.csv
# [stdout]  9937/10000: success; runtime=   1.759 s; num_steps=    6551;   |   p_A=-1.7475e+05 Pa; freq=2.0000e+04 Hz;    |   energy_demand=5.1254e+07 MJ/kg (best=7.3380e+02 MJ/kg)
# [stdout] test.csv
# [stdout]  9938/10000: success; runtime=   1.693 s; num_steps=    6716;   |   p_A=-1.7677e+05 Pa; freq=2.0000e+04 Hz;    |   energy_demand=4.3320e+07 MJ/kg (best=7.3380e+02 MJ/kg)
# [stdout] test.csv
# [stdout]  9939/10000: success; runtime=   1.652 s; num_steps=    6762;   |   p_A=-1.7879e+05 Pa; freq=2.0000e+04 Hz;    |   energy_demand=5.1382e+07 MJ/kg (best=7.3380e+02 MJ/kg)
# [stdout] test.csv
# [stdout]  9940/10000: success; runtime=   1.688 s; num_steps=    6635;   |   p_A=-1.8081e+05 Pa; freq=2.0000e+04 Hz;    |   energy_demand=4.4755e+07 MJ/kg (best=7.3380e+02 MJ/kg)
# [stdout] test.csv
# [stdout]  9941/10000: success; runtime=   1.714 s; num_steps=    6962;   |   p_A=-1.8283e+05 Pa; freq=2.0000e+04 Hz;    |   energy_demand=4.8726e+07 MJ/kg (best=7.3380e+02 MJ/kg)
# [stdout] test.csv
# [stdout]  9942/10000: success; runtime=   1.582 s; num_steps=    6417;   |   p_A=-1.8485e+05 Pa; freq=2.0000e+04 Hz;    |   energy_demand=6.6270e+07 MJ/kg (best=7.3380e+02 MJ/kg)
# [stdout] test.csv
# [stdout]  9943/10000: success; runtime=   1.582 s; num_steps=    6496;   |   p_A=-1.8687e+05 Pa; freq=2.0000e+04 Hz;    |   energy_demand=5.5544e+07 MJ/kg (best=7.3380e+02 MJ/kg)
# [stdout] test.csv
# [stdout]  9944/10000: success; runtime=   1.761 s; num_steps=    7054;   |   p_A=-1.8889e+05 Pa; freq=2.0000e+04 Hz;    |   energy_demand=6.1448e+07 MJ/kg (best=7.3380e+02 MJ/kg)
# [stdout] test.csv
# [stdout]  9945/10000: success; runtime=   1.483 s; num_steps=    6607;   |   p_A=-1.9091e+05 Pa; freq=2.0000e+04 Hz;    |   energy_demand=7.3943e+07 MJ/kg (best=7.3380e+02 MJ/kg)
# [stdout] test.csv
# [stdout]  9947/10000: success; runtime=   1.717 s; num_steps=    6628;   |   p_A=-1.9495e+05 Pa; freq=2.0000e+04 Hz;    |   energy_demand=5.1298e+07 MJ/kg (best=7.3380e+02 MJ/kg)
# [stdout] test.csv
# [stdout]  9946/10000: success; runtime=   1.937 s; num_steps=    6749;   |   p_A=-1.9293e+05 Pa; freq=2.0000e+04 Hz;    |   energy_demand=8.2578e+07 MJ/kg (best=7.3380e+02 MJ/kg)
# [stdout] test.csv
# [stdout]  9948/10000: success; runtime=   1.842 s; num_steps=    6842;   |   p_A=-1.9697e+05 Pa; freq=2.0000e+04 Hz;    |   energy_demand=5.2715e+07 MJ/kg (best=7.3380e+02 MJ/kg)
# [stdout] test.csv
# [stdout]  9949/10000: success; runtime=   1.906 s; num_steps=    6964;   |   p_A=-1.9899e+05 Pa; freq=2.0000e+04 Hz;    |   energy_demand=6.1810e+07 MJ/kg (best=7.3380e+02 MJ/kg)
# [stdout] test.csv
# [stdout]  9951/10000: success; runtime=   1.679 s; num_steps=    6732;   |   p_A=-2.0303e+05 Pa; freq=2.0000e+04 Hz;    |   energy_demand=5.6014e+07 MJ/kg (best=7.3380e+02 MJ/kg)
# [stdout] test.csv
# [stdout]  9950/10000: success; runtime=   1.845 s; num_steps=    6920;   |   p_A=-2.0101e+05 Pa; freq=2.0000e+04 Hz;    |   energy_demand=6.8966e+07 MJ/kg (best=7.3380e+02 MJ/kg)
# [stdout] test.csv
# [stdout]  9952/10000: success; runtime=   1.692 s; num_steps=    6760;   |   p_A=-2.0505e+05 Pa; freq=2.0000e+04 Hz;    |   energy_demand=6.0606e+07 MJ/kg (best=7.3380e+02 MJ/kg)
# [stdout] test.csv
# [stdout]  9953/10000: success; runtime=   1.667 s; num_steps=    6689;   |   p_A=-2.0707e+05 Pa; freq=2.0000e+04 Hz;    |   energy_demand=6.7942e+07 MJ/kg (best=7.3380e+02 MJ/kg)
# [stdout] test.csv
# [stdout]  9955/10000: success; runtime=   1.679 s; num_steps=    6862;   |   p_A=-2.1111e+05 Pa; freq=2.0000e+04 Hz;    |   energy_demand=1.1262e+08 MJ/kg (best=7.3380e+02 MJ/kg)
# [stdout] test.csv
# [stdout]  9954/10000: success; runtime=   1.766 s; num_steps=    6800;   |   p_A=-2.0909e+05 Pa; freq=2.0000e+04 Hz;    |   energy_demand=8.9793e+07 MJ/kg (best=7.3380e+02 MJ/kg)
# [stdout] test.csv
# [stdout]  9956/10000: success; runtime=   1.659 s; num_steps=    6694;   |   p_A=-2.1313e+05 Pa; freq=2.0000e+04 Hz;    |   energy_demand=6.0273e+07 MJ/kg (best=7.3380e+02 MJ/kg)
# [stdout] test.csv
# [stdout]  9957/10000: success; runtime=   1.654 s; num_steps=    6661;   |   p_A=-2.1515e+05 Pa; freq=2.0000e+04 Hz;    |   energy_demand=6.4439e+07 MJ/kg (best=7.3380e+02 MJ/kg)
# [stdout] test.csv
# [stdout]  9958/10000: success; runtime=   1.682 s; num_steps=    6730;   |   p_A=-2.1717e+05 Pa; freq=2.0000e+04 Hz;    |   energy_demand=1.1420e+08 MJ/kg (best=7.3380e+02 MJ/kg)
# [stdout] test.csv
# [stdout]  9959/10000: success; runtime=   1.645 s; num_steps=    6733;   |   p_A=-2.1919e+05 Pa; freq=2.0000e+04 Hz;    |   energy_demand=7.4602e+07 MJ/kg (best=7.3380e+02 MJ/kg)
# [stdout] test.csv
# [stdout]  9960/10000: success; runtime=   1.801 s; num_steps=    6883;   |   p_A=-2.2121e+05 Pa; freq=2.0000e+04 Hz;    |   energy_demand=5.5305e+07 MJ/kg (best=7.3380e+02 MJ/kg)
# [stdout] test.csv
# [stdout]  9961/10000: success; runtime=   1.802 s; num_steps=    6891;   |   p_A=-2.2323e+05 Pa; freq=2.0000e+04 Hz;    |   energy_demand=8.7198e+07 MJ/kg (best=7.3380e+02 MJ/kg)
# [stdout] test.csv
# [stdout]  9962/10000: success; runtime=   1.641 s; num_steps=    6720;   |   p_A=-2.2525e+05 Pa; freq=2.0000e+04 Hz;    |   energy_demand=1.6386e+08 MJ/kg (best=7.3380e+02 MJ/kg)
# [stdout] test.csv
# [stdout]  9963/10000: success; runtime=   1.705 s; num_steps=    6695;   |   p_A=-2.2727e+05 Pa; freq=2.0000e+04 Hz;    |   energy_demand=2.3721e+07 MJ/kg (best=7.3380e+02 MJ/kg)
# [stdout] test.csv
# [stdout]  9964/10000: success; runtime=   1.686 s; num_steps=    6892;   |   p_A=-2.2929e+05 Pa; freq=2.0000e+04 Hz;    |   energy_demand=1.2604e+08 MJ/kg (best=7.3380e+02 MJ/kg)
# [stdout] test.csv
# [stdout]  9965/10000: success; runtime=   1.715 s; num_steps=    6918;   |   p_A=-2.3131e+05 Pa; freq=2.0000e+04 Hz;    |   energy_demand=9.7000e+07 MJ/kg (best=7.3380e+02 MJ/kg)
# [stdout] test.csv
# [stdout]  9966/10000: success; runtime=   1.769 s; num_steps=    6829;   |   p_A=-2.3333e+05 Pa; freq=2.0000e+04 Hz;    |   energy_demand=8.0782e+07 MJ/kg (best=7.3380e+02 MJ/kg)
# [stdout] test.csv
# [stdout]  9967/10000: success; runtime=   1.832 s; num_steps=    6972;   |   p_A=-2.3535e+05 Pa; freq=2.0000e+04 Hz;    |   energy_demand=5.0985e+07 MJ/kg (best=7.3380e+02 MJ/kg)
# [stdout] test.csv
# [stdout]  9968/10000: success; runtime=   1.798 s; num_steps=    6866;   |   p_A=-2.3737e+05 Pa; freq=2.0000e+04 Hz;    |   energy_demand=8.5941e+07 MJ/kg (best=7.3380e+02 MJ/kg)
# [stdout] test.csv
# [stdout]  9969/10000: success; runtime=   1.867 s; num_steps=    7013;   |   p_A=-2.3939e+05 Pa; freq=2.0000e+04 Hz;    |   energy_demand=7.8005e+07 MJ/kg (best=7.3380e+02 MJ/kg)
# [stdout] test.csv
# [stdout]  9970/10000: success; runtime=   2.030 s; num_steps=    7017;   |   p_A=-2.4141e+05 Pa; freq=2.0000e+04 Hz;    |   energy_demand=1.4793e+08 MJ/kg (best=7.3380e+02 MJ/kg)
# [stdout] test.csv
# [stdout]  9971/10000: success; runtime=   1.982 s; num_steps=    7149;   |   p_A=-2.4343e+05 Pa; freq=2.0000e+04 Hz;    |   energy_demand=4.3466e+07 MJ/kg (best=7.3380e+02 MJ/kg)
# [stdout] test.csv
# [stdout]  9972/10000: success; runtime=   2.087 s; num_steps=    7373;   |   p_A=-2.4545e+05 Pa; freq=2.0000e+04 Hz;    |   energy_demand=6.4396e+07 MJ/kg (best=7.3380e+02 MJ/kg)
# [stdout] test.csv
# [stdout]  9973/10000: success; runtime=   2.087 s; num_steps=    7166;   |   p_A=-2.4747e+05 Pa; freq=2.0000e+04 Hz;    |   energy_demand=6.2574e+07 MJ/kg (best=7.3380e+02 MJ/kg)
# [stdout] test.csv
# [stdout]  9974/10000: success; runtime=   1.974 s; num_steps=    7167;   |   p_A=-2.4949e+05 Pa; freq=2.0000e+04 Hz;    |   energy_demand=8.1119e+07 MJ/kg (best=7.3380e+02 MJ/kg)
# [stdout] test.csv
# [stdout]  9975/10000: success; runtime=   2.031 s; num_steps=    7129;   |   p_A=-2.5152e+05 Pa; freq=2.0000e+04 Hz;    |   energy_demand=5.8131e+07 MJ/kg (best=7.3380e+02 MJ/kg)
# [stdout] test.csv
# [stdout]  9976/10000: success; runtime=   2.006 s; num_steps=    7100;   |   p_A=-2.5354e+05 Pa; freq=2.0000e+04 Hz;    |   energy_demand=2.7984e+07 MJ/kg (best=7.3380e+02 MJ/kg)
# [stdout] test.csv
# [stdout]  9977/10000: success; runtime=   1.953 s; num_steps=    7175;   |   p_A=-2.5556e+05 Pa; freq=2.0000e+04 Hz;    |   energy_demand=3.2523e+07 MJ/kg (best=7.3380e+02 MJ/kg)
# [stdout] test.csv
# [stdout]  9978/10000: success; runtime=   1.903 s; num_steps=    7333;   |   p_A=-2.5758e+05 Pa; freq=2.0000e+04 Hz;    |   energy_demand=6.0735e+07 MJ/kg (best=7.3380e+02 MJ/kg)
# [stdout] test.csv
# [stdout]  9979/10000: success; runtime=   1.881 s; num_steps=    7361;   |   p_A=-2.5960e+05 Pa; freq=2.0000e+04 Hz;    |   energy_demand=4.3420e+07 MJ/kg (best=7.3380e+02 MJ/kg)
# [stdout] test.csv
# [stdout]  9980/10000: success; runtime=   1.871 s; num_steps=    7271;   |   p_A=-2.6162e+05 Pa; freq=2.0000e+04 Hz;    |   energy_demand=4.4450e+07 MJ/kg (best=7.3380e+02 MJ/kg)
# [stdout] test.csv
# [stdout]  9981/10000: success; runtime=   1.932 s; num_steps=    7293;   |   p_A=-2.6364e+05 Pa; freq=2.0000e+04 Hz;    |   energy_demand=2.5148e+07 MJ/kg (best=7.3380e+02 MJ/kg)
# [stdout] test.csv
# [stdout]  9982/10000: success; runtime=   1.944 s; num_steps=    7309;   |   p_A=-2.6566e+05 Pa; freq=2.0000e+04 Hz;    |   energy_demand=3.1173e+07 MJ/kg (best=7.3380e+02 MJ/kg)
# [stdout] test.csv
# [stdout]  9983/10000: success; runtime=   1.917 s; num_steps=    7194;   |   p_A=-2.6768e+05 Pa; freq=2.0000e+04 Hz;    |   energy_demand=4.7405e+07 MJ/kg (best=7.3380e+02 MJ/kg)
# [stdout] test.csv
# [stdout]  9984/10000: success; runtime=   1.969 s; num_steps=    7277;   |   p_A=-2.6970e+05 Pa; freq=2.0000e+04 Hz;    |   energy_demand=4.6889e+07 MJ/kg (best=7.3380e+02 MJ/kg)
# [stdout] test.csv
# [stdout]  9985/10000: success; runtime=   1.903 s; num_steps=    7263;   |   p_A=-2.7172e+05 Pa; freq=2.0000e+04 Hz;    |   energy_demand=6.3117e+07 MJ/kg (best=7.3380e+02 MJ/kg)
# [stdout] test.csv
# [stdout]  9986/10000: success; runtime=   2.029 s; num_steps=    7227;   |   p_A=-2.7374e+05 Pa; freq=2.0000e+04 Hz;    |   energy_demand=2.8837e+07 MJ/kg (best=7.3380e+02 MJ/kg)
# [stdout] test.csv
# [stdout]  9987/10000: success; runtime=   2.006 s; num_steps=    7264;   |   p_A=-2.7576e+05 Pa; freq=2.0000e+04 Hz;    |   energy_demand=1.9754e+07 MJ/kg (best=7.3380e+02 MJ/kg)
# [stdout] test.csv
# [stdout]  9988/10000: success; runtime=   2.132 s; num_steps=    7239;   |   p_A=-2.7778e+05 Pa; freq=2.0000e+04 Hz;    |   energy_demand=3.4000e+07 MJ/kg (best=7.3380e+02 MJ/kg)
# [stdout] test.csv
# [stdout]  9989/10000: success; runtime=   2.079 s; num_steps=    7326;   |   p_A=-2.7980e+05 Pa; freq=2.0000e+04 Hz;    |   energy_demand=3.6931e+07 MJ/kg (best=7.3380e+02 MJ/kg)
# [stdout] test.csv
# [stdout]  9990/10000: success; runtime=   2.059 s; num_steps=    7376;   |   p_A=-2.8182e+05 Pa; freq=2.0000e+04 Hz;    |   energy_demand=2.7798e+07 MJ/kg (best=7.3380e+02 MJ/kg)
# [stdout] test.csv
# [stdout]  9991/10000: success; runtime=   2.172 s; num_steps=    7520;   |   p_A=-2.8384e+05 Pa; freq=2.0000e+04 Hz;    |   energy_demand=3.3863e+07 MJ/kg (best=7.3380e+02 MJ/kg)
# [stdout] test.csv
# [stdout]  9992/10000: success; runtime=   2.031 s; num_steps=    7536;   |   p_A=-2.8586e+05 Pa; freq=2.0000e+04 Hz;    |   energy_demand=2.5229e+07 MJ/kg (best=7.3380e+02 MJ/kg)
# [stdout]  9993/10000: success; runtime=   2.165 s; num_steps=    7527;   |   p_A=-2.8788e+05 Pa; freq=2.0000e+04 Hz;    |   energy_demand=2.8583e+07 MJ/kg (best=7.3380e+02 MJ/kg)
# [stdout]  9995/10000: success; runtime=   1.882 s; num_steps=    7552;   |   p_A=-2.9192e+05 Pa; freq=2.0000e+04 Hz;    |   energy_demand=2.1324e+07 MJ/kg (best=7.3380e+02 MJ/kg)
# [stdout]  9994/10000: success; runtime=   1.996 s; num_steps=    7587;   |   p_A=-2.8990e+05 Pa; freq=2.0000e+04 Hz;    |   energy_demand=2.6548e+07 MJ/kg (best=7.3380e+02 MJ/kg)
# [stdout]  9996/10000: success; runtime=   1.917 s; num_steps=    7571;   |   p_A=-2.9394e+05 Pa; freq=2.0000e+04 Hz;    |   energy_demand=1.9515e+07 MJ/kg (best=7.3380e+02 MJ/kg)
# [stdout]  9998/10000: success; runtime=   1.688 s; num_steps=    7639;   |   p_A=-2.9798e+05 Pa; freq=2.0000e+04 Hz;    |   energy_demand=2.6183e+07 MJ/kg (best=7.3380e+02 MJ/kg)
# [stdout]  9997/10000: success; runtime=   1.807 s; num_steps=    7665;   |   p_A=-2.9596e+05 Pa; freq=2.0000e+04 Hz;    |   energy_demand=1.9168e+07 MJ/kg (best=7.3380e+02 MJ/kg)
# [stdout]  9999/10000: success; runtime=   1.678 s; num_steps=    7757;   |   p_A=-3.0000e+05 Pa; freq=2.0000e+04 Hz;    |   energy_demand=1.9464e+07 MJ/kg (best=7.3380e+02 MJ/kg)
# [stdout]
# [stdout]
# [stdout] Successful simulations: 9968/10000 (99.68 %)
# [stdout] Total runtime: 2844.554 s
# [stdout] Average runtime per combination: 284.46 ms
#
# ./bin/main returned with code 1 after 2849.1991 seconds.
# Found files:
# _______________________________________
# total:    0 rows in  0 files

# %%
print('Please check if the data in parameters.py is correct (accurate mechanism...)!')
class dotdict(dict):
    __getattr__ = dict.get
    __setattr__ = dict.__setitem__
    __delattr__ = dict.__delitem__

import importlib   # For reloading your own files
import full_bubble_model as de
importlib.reload(de)
import parameters as par   # numeric constants and coefficents
importlib.reload(par)   # reload changes you made
file = de.Make_dir('_test', separator=',')   # it makes a folder named 'test' in which it will save data
num_sol=data['sol']
error_code=-1
elapsed_time=-1

num_sol = dotdict(data['sol'])
num_sol.y = num_sol.x.T.copy()
#num_sol.y[3:-1,:] = num_sol.y[3:-1,:]*1.0e-6#*1.0e-6: mol/m^3->mol/cm^3
#!!!! data.success = num_sol.success

data2 = de.get_data(cpar, num_sol, error_code, elapsed_time)   # post processing
file.write_solution(data2, num_sol, 'testfile')   # saving (it overwrites data)
